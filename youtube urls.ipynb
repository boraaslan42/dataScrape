# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium_stealth import stealth


options = Options()
options.add_argument("start-maximized")

options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
s = Service('C:\\BrowserDrivers\\chromedriver.exe')
driver = webdriver.Chrome(service=s, options=options)

stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )

# %%
def videoUrl(pageNO):
    search_url="https://www.google.com/search?q=Tesla+Model+3+accessories+youtube&client=opera-gx&hs=b5L&tbm=vid&sxsrf=AB5stBiskZyBSa-_sSTzjO4SfLaXKiBX2g:1688860804954&ei=hPipZPXwOfySxc8P16eUOA&start="+str((pageNO-1)*10)+"&sa=N&ved=2ahUKEwj1wuriqICAAxV8SfEDHdcTBQc4ChDy0wN6BAgPEAc&biw=1707&bih=804&dpr=1.13"
    driver.get(search_url)

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    search = soup.find("div", {"id": "search"})
    b = search.find_all("div", {"class": "g"})

    print("page:",pageNO)

    for j in range(0, 10):
        print("video:",(pageNO-1)*10+j+1)
        for i in b[j].find_all("div"):
            try:
                print(i.find("div").find("div").find("div").find("a")["href"])
            except:
                continue
            break
for i in range(1,11):
    videoUrl(i)
    
"""for i in range(0,10):
    print(i)
    if i==0:
        print(b[0].find("div").find("div").find("div").find("a")["href"])
    else:
        print(b[i].find_all("div")[6].find("a")["href"])
"""


# print(b[3].find_all("div")[6].find("a")["href"])
"""print(b[1])
print(b[1].find_all("div"))"""

# print(b[0].find("div").find("div").find("div").find("a")["href"])
# Out:
# page: 1
# video: 1
# https://www.youtube.com/watch?v=-Y-hkwPSazY
# video: 2
# https://www.youtube.com/watch?v=oy3QynkPlbw
# video: 3
# https://www.youtube.com/watch?v=FQaRgfI4aPY
# video: 4
# https://www.youtube.com/watch?v=lHoeuRbDq4c
# video: 5
# https://www.youtube.com/watch?v=CsFwf-7uUHs
# video: 6
# https://www.youtube.com/watch?v=VmnsmZnXslw
# video: 7
# https://www.youtube.com/watch?v=EIy_DByjKmw
# video: 8
# https://www.youtube.com/watch?v=OB8JfqJKSlk
# video: 9
# https://www.youtube.com/watch?v=bEAAYodXYzY
# video: 10
# https://www.youtube.com/watch?v=pskVUkfNXa0
# page: 2
# video: 11
# https://www.youtube.com/watch?v=KG0wOnGvfdU
# video: 12
# https://www.youtube.com/watch?v=Acj9GYeOHpU
# video: 13
# https://www.youtube.com/watch?v=bFueALlW1tU
# video: 14
# https://www.youtube.com/watch?v=qoysS-GC0A4
# video: 15
# https://www.youtube.com/watch?v=ovtGOb5Ml7g
# video: 16
# https://www.youtube.com/watch?v=r8CkYMoz63U
# video: 17
# https://www.youtube.com/watch?v=JxynaCn0hM4
# ...
